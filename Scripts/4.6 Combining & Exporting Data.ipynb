# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\anish\02-2025 Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\anish\\02-2025 Instacart Basket Analysis'

# %%
# Question 3
orders_products_combined = pd.read_pickle(os.path.join(path, 'Data' , 'Prepared Data' , 'orders_products_combined.pkl'))
df_prods = pd.read_csv(os.path.join(path, 'Data' , 'Prepared Data' , 'product_checked.csv'), index_col = 0)

# %%
# Question 4
orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  orders_hour  \
# 0   2539329        1             1                   2            8
# 1   2539329        1             1                   2            8
# 2   2539329        1             1                   2            8
# 3   2539329        1             1                   2            8
# 4   2539329        1             1                   2            8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
df_prods.shape
# Out:
# (49677, 5)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# Question 5-6
pd.merge(orders_products_combined , df_prods , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#           order_id  user_id  order_number  orders_day_of_week  orders_hour  \
# 0          2539329        1             1                   2            8
# 1          2539329        1             1                   2            8
# 2          2539329        1             1                   2            8
# 3          2539329        1             1                   2            8
# 4          2539329        1             1                   2            8
# ...            ...      ...           ...                 ...          ...
# 32406036   2977660   206209            13                   1           12
# 32406037   2977660   206209            13                   1           12
# 32406038   2977660   206209            13                   1           12
# 32406039   2977660   206209            13                   1           12
# 32406040   2977660   206209            13                   1           12
#
# ...

# %%
ords_prods_merge = orders_products_combined.merge(df_prods , on = ['product_id'] , indicator = 'match' )

# %%
ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#           order_id  user_id  order_number  orders_day_of_week  orders_hour  \
# 0          2539329        1             1                   2            8
# 1          2539329        1             1                   2            8
# 2          2539329        1             1                   2            8
# 3          2539329        1             1                   2            8
# 4          2539329        1             1                   2            8
# ...            ...      ...           ...                 ...          ...
# 32406036   2977660   206209            13                   1           12
# 32406037   2977660   206209            13                   1           12
# 32406038   2977660   206209            13                   1           12
# 32406039   2977660   206209            13                   1           12
# 32406040   2977660   206209            13                   1           12
#
# ...

# %% [markdown]
# merged using the common column "product_id". Dropped the merge column afterwards as it is not neccessary. Inner join was the best for this task/project.

# %%
ords_prods_merge['_merge'].value_counts()
# Out:
# _merge
# both          32406041
# left_only            0
# right_only           0
# Name: count, dtype: int64

# %%
# Export
ords_prods_merge.to_pickle(os.path.join(path, 'Data','Prepared Data', 'ords_prods_merge.pkl'))
