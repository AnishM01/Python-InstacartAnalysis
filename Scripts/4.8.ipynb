# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %%
path = r"C:\Users\anish\02-2025 Instacart Basket Analysis"

# %%
path
# Out:
# 'C:\\Users\\anish\\02-2025 Instacart Basket Analysis'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, 'Data' , 'Prepared Data' , 'orders_products_merged_derived.pkl'))

# %% [markdown]
# ## Question 2

# %%
df_ords_prods_merge.groupby('department_id').agg({'order_number' : ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.213779
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.171095
# 12               15.887671
# 13               16.583536
# 14               16.771241
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ## Question 3

# %% [markdown]
# Compared to the subset, the entire dataframe has a higher mean order numbers across the departments. We can assume that it captured a broader range of customer behaviors compared to the subset. Some departments's mean value are higher or lower compared to the subset.

# %% [markdown]
# ## Question 4

# %%
df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_9288\136815596.py:1: FutureWarning: The provided callable <function max at 0x0000023270838360> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df_ords_prods_merge['max_order'] = df_ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
df_ords_prods_merge.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  orders_hour  \
# 0    2539329        1             1                   2            8
# 1    2539329        1             1                   2            8
# 2    2539329        1             1                   2            8
# 3    2539329        1             1                   2            8
# 4    2539329        1             1                   2            8
# 5    2398795        1             2                   3            7
# 6    2398795        1             2                   3            7
# 7    2398795        1             2                   3            7
# 8    2398795        1             2                   3            7
# 9    2398795        1             2                   3            7
# 10   2398795        1             2                   3            7
# 11    473747        1             3                   3           12
# 12    473747        1             3                   3           12
# 13    473747        1             3                   3           12
# 14    473747        1             3                   3           12
# 15    473747        1             3                   3           12
# 16   2254736        1             4                   4            7
# 17   2254736        1             4                   4            7
# 18   2254736        1             4                   4            7
# 19   2254736        1             4                   4            7
# 20   2254736        1             4                   4            7
# 21    431534        1             5                   4           15
# 22    431534        1             5                   4           15
# 23    431534        1             5                   4           15
# 24    431534        1             5                   4           15
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                      NaN       14084                  2          0   both
# 2                      NaN       12427                  3          0   both
# 3                      NaN       26088                  4          0   both
# 4                      NaN       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
# 15                    21.0       30450                  5          0   both
# 16                    29.0         196                  1          1   both
# 17                    29.0       12427                  2          1   both
# 18                    29.0       10258                  3          1   both
# 19                    29.0       25133                  4          1   both
# 20                    29.0       26405                  5          1   both
# 21                    28.0         196                  1          1   both
# 22                    28.0       12427                  2          1   both
# 23                    28.0       10258                  3          1   both
# 24                    28.0       25133                  4          1   both
#
#                                product_name  aisle_id  department_id  prices  \
# 0                                      Soda        77              7     9.0
# 1   Organic Unsweetened Vanilla Almond Milk        91             16    12.5
# 2                       Original Beef Jerky        23             19     4.4
# 3                Aged White Cheddar Popcorn        23             19     4.7
# 4          XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 5                                      Soda        77              7     9.0
# 6                                Pistachios       117             19     3.0
# 7                       Original Beef Jerky        23             19     4.4
# 8                    Bag of Organic Bananas        24              4    10.3
# 9                Aged White Cheddar Popcorn        23             19     4.7
# 10                    Cinnamon Toast Crunch       121             14     4.0
# 11                                     Soda        77              7     9.0
# 12                      Original Beef Jerky        23             19     4.4
# 13                               Pistachios       117             19     3.0
# 14                    Organic String Cheese        21             16     8.6
# 15                     Creamy Almond Butter        88             13     3.2
# 16                                     Soda        77              7     9.0
# 17                      Original Beef Jerky        23             19     4.4
# 18                               Pistachios       117             19     3.0
# 19                    Organic String Cheese        21             16     8.6
# 20         XL Pick-A-Size Paper Towel Rolls        54             17     1.0
# 21                                     Soda        77              7     9.0
# 22                      Original Beef Jerky        23             19     4.4
# 23                               Pistachios       117             19     3.0
# 24                    Organic String Cheese        21             16     8.6
#
#    match    price_range_loc     busiest_day       busiest_days  \
# 0   both  Mid-range product  Regularly busy  Average busy days
# 1   both  Mid-range product  Regularly busy  Average busy days
# 2   both  Low-range product  Regularly busy  Average busy days
# 3   both  Low-range product  Regularly busy  Average busy days
# 4   both  Low-range product  Regularly busy  Average busy days
# 5   both  Mid-range product  Regularly busy       Slowest days
# 6   both  Low-range product  Regularly busy       Slowest days
# 7   both  Low-range product  Regularly busy       Slowest days
# 8   both  Mid-range product  Regularly busy       Slowest days
# 9   both  Low-range product  Regularly busy       Slowest days
# 10  both  Low-range product  Regularly busy       Slowest days
# 11  both  Mid-range product  Regularly busy       Slowest days
# 12  both  Low-range product  Regularly busy       Slowest days
# 13  both  Low-range product  Regularly busy       Slowest days
# 14  both  Mid-range product  Regularly busy       Slowest days
# 15  both  Low-range product  Regularly busy       Slowest days
# 16  both  Mid-range product      Least busy       Slowest days
# 17  both  Low-range product      Least busy       Slowest days
# 18  both  Low-range product      Least busy       Slowest days
# 19  both  Mid-range product      Least busy       Slowest days
# 20  both  Low-range product      Least busy       Slowest days
# 21  both  Mid-range product      Least busy       Slowest days
# 22  both  Low-range product      Least busy       Slowest days
# 23  both  Low-range product      Least busy       Slowest days
# 24  both  Mid-range product      Least busy       Slowest days
#
#    busiest_period_of_day  max_order
# 0         Average orders         10
# 1         Average orders         10
# 2         Average orders         10
# 3         Average orders         10
# 4         Average orders         10
# 5         Average orders         10
# 6         Average orders         10
# 7         Average orders         10
# 8         Average orders         10
# 9         Average orders         10
# 10        Average orders         10
# 11           Most orders         10
# 12           Most orders         10
# 13           Most orders         10
# 14           Most orders         10
# 15           Most orders         10
# 16        Average orders         10
# 17        Average orders         10
# 18        Average orders         10
# 19        Average orders         10
# 20        Average orders         10
# 21           Most orders         10
# 22           Most orders         10
# 23           Most orders         10
# 24           Most orders         10

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['max_order'] <= 40) & (df_ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
df_ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15877395
# Loyal customer      10284396
# New customer         6244250
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head(25)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  orders_hour  \
# 0    2539329        1             1                   2            8
# 1    2539329        1             1                   2            8
# 2    2539329        1             1                   2            8
# 3    2539329        1             1                   2            8
# 4    2539329        1             1                   2            8
# 5    2398795        1             2                   3            7
# 6    2398795        1             2                   3            7
# 7    2398795        1             2                   3            7
# 8    2398795        1             2                   3            7
# 9    2398795        1             2                   3            7
# 10   2398795        1             2                   3            7
# 11    473747        1             3                   3           12
# 12    473747        1             3                   3           12
# 13    473747        1             3                   3           12
# 14    473747        1             3                   3           12
# 15    473747        1             3                   3           12
# 16   2254736        1             4                   4            7
# 17   2254736        1             4                   4            7
# 18   2254736        1             4                   4            7
# 19   2254736        1             4                   4            7
# 20   2254736        1             4                   4            7
# 21    431534        1             5                   4           15
# 22    431534        1             5                   4           15
# 23    431534        1             5                   4           15
# 24    431534        1             5                   4           15
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                      NaN         196                  1          0   both
# 1                      NaN       14084                  2          0   both
# 2                      NaN       12427                  3          0   both
# 3                      NaN       26088                  4          0   both
# 4                      NaN       26405                  5          0   both
# 5                     15.0         196                  1          1   both
# 6                     15.0       10258                  2          0   both
# 7                     15.0       12427                  3          1   both
# 8                     15.0       13176                  4          0   both
# 9                     15.0       26088                  5          1   both
# 10                    15.0       13032                  6          0   both
# 11                    21.0         196                  1          1   both
# 12                    21.0       12427                  2          1   both
# 13                    21.0       10258                  3          1   both
# 14                    21.0       25133                  4          0   both
# 15                    21.0       30450                  5          0   both
# 16                    29.0         196                  1          1   both
# 17                    29.0       12427                  2          1   both
# 18                    29.0       10258                  3          1   both
# 19                    29.0       25133                  4          1   both
# 20                    29.0       26405                  5          1   both
# 21                    28.0         196                  1          1   both
# 22                    28.0       12427                  2          1   both
# 23                    28.0       10258                  3          1   both
# 24                    28.0       25133                  4          1   both
#
#     ... aisle_id  department_id  prices  match    price_range_loc  \
# 0   ...       77              7     9.0   both  Mid-range product
# 1   ...       91             16    12.5   both  Mid-range product
# 2   ...       23             19     4.4   both  Low-range product
# 3   ...       23             19     4.7   both  Low-range product
# 4   ...       54             17     1.0   both  Low-range product
# 5   ...       77              7     9.0   both  Mid-range product
# 6   ...      117             19     3.0   both  Low-range product
# 7   ...       23             19     4.4   both  Low-range product
# 8   ...       24              4    10.3   both  Mid-range product
# 9   ...       23             19     4.7   both  Low-range product
# 10  ...      121             14     4.0   both  Low-range product
# 11  ...       77              7     9.0   both  Mid-range product
# 12  ...       23             19     4.4   both  Low-range product
# 13  ...      117             19     3.0   both  Low-range product
# 14  ...       21             16     8.6   both  Mid-range product
# 15  ...       88             13     3.2   both  Low-range product
# 16  ...       77              7     9.0   both  Mid-range product
# 17  ...       23             19     4.4   both  Low-range product
# 18  ...      117             19     3.0   both  Low-range product
# 19  ...       21             16     8.6   both  Mid-range product
# 20  ...       54             17     1.0   both  Low-range product
# 21  ...       77              7     9.0   both  Mid-range product
# 22  ...       23             19     4.4   both  Low-range product
# 23  ...      117             19     3.0   both  Low-range product
# 24  ...       21             16     8.6   both  Mid-range product
#
#        busiest_day       busiest_days busiest_period_of_day max_order  \
# 0   Regularly busy  Average busy days        Average orders        10
# 1   Regularly busy  Average busy days        Average orders        10
# 2   Regularly busy  Average busy days        Average orders        10
# 3   Regularly busy  Average busy days        Average orders        10
# 4   Regularly busy  Average busy days        Average orders        10
# 5   Regularly busy       Slowest days        Average orders        10
# 6   Regularly busy       Slowest days        Average orders        10
# 7   Regularly busy       Slowest days        Average orders        10
# 8   Regularly busy       Slowest days        Average orders        10
# 9   Regularly busy       Slowest days        Average orders        10
# 10  Regularly busy       Slowest days        Average orders        10
# 11  Regularly busy       Slowest days           Most orders        10
# 12  Regularly busy       Slowest days           Most orders        10
# 13  Regularly busy       Slowest days           Most orders        10
# 14  Regularly busy       Slowest days           Most orders        10
# 15  Regularly busy       Slowest days           Most orders        10
# 16      Least busy       Slowest days        Average orders        10
# 17      Least busy       Slowest days        Average orders        10
# 18      Least busy       Slowest days        Average orders        10
# 19      Least busy       Slowest days        Average orders        10
# 20      Least busy       Slowest days        Average orders        10
# 21      Least busy       Slowest days           Most orders        10
# 22      Least busy       Slowest days           Most orders        10
# 23      Least busy       Slowest days           Most orders        10
# 24      Least busy       Slowest days           Most orders        10
#
#     loyalty_flag
# 0   New customer
# 1   New customer
# 2   New customer
# 3   New customer
# 4   New customer
# 5   New customer
# 6   New customer
# 7   New customer
# 8   New customer
# 9   New customer
# 10  New customer
# 11  New customer
# 12  New customer
# 13  New customer
# 14  New customer
# 15  New customer
# 16  New customer
# 17  New customer
# 18  New customer
# 19  New customer
# 20  New customer
# 21  New customer
# 22  New customer
# 23  New customer
# 24  New customer
#
# [25 rows x 21 columns]

# %% [markdown]
# ## Question 5

# %%
df_ords_prods_merge.groupby('loyalty_flag').agg({'prices' : ['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386229  1.0  99999.0
# New customer      13.294406  1.0  99999.0
# Regular customer  12.495501  1.0  99999.0

# %% [markdown]
# Loyal customers tend to spend less as their mean is the least, while new customers spend the most with their mean being the highest. Regular customers are in the middle.

# %% [markdown]
# ## Question 6

# %%
df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_9288\3788972221.py:1: FutureWarning: The provided callable <function mean at 0x0000023270838D60> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   df_ords_prods_merge['avg_product_price'] = df_ords_prods_merge.groupby(['user_id'])['prices'].transform(np.mean)

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] >= 10, 'spending_flag'] = 'High spender'
df_ords_prods_merge.loc[df_ords_prods_merge['avg_product_price'] < 10, 'spending_flag'] = 'Low spender'

# %%
df_ords_prods_merge['spending_flag'].value_counts(dropna = False)
# Out:
# spending_flag
# Low spender     31771789
# High spender      634252
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'avg_product_price', 'spending_flag']].head(50)
# Out:
#     user_id  avg_product_price spending_flag
# 0         1           6.367797   Low spender
# 1         1           6.367797   Low spender
# 2         1           6.367797   Low spender
# 3         1           6.367797   Low spender
# 4         1           6.367797   Low spender
# 5         1           6.367797   Low spender
# 6         1           6.367797   Low spender
# 7         1           6.367797   Low spender
# 8         1           6.367797   Low spender
# 9         1           6.367797   Low spender
# 10        1           6.367797   Low spender
# 11        1           6.367797   Low spender
# 12        1           6.367797   Low spender
# 13        1           6.367797   Low spender
# 14        1           6.367797   Low spender
# 15        1           6.367797   Low spender
# 16        1           6.367797   Low spender
# 17        1           6.367797   Low spender
# 18        1           6.367797   Low spender
# 19        1           6.367797   Low spender
# 20        1           6.367797   Low spender
# 21        1           6.367797   Low spender
# 22        1           6.367797   Low spender
# 23        1           6.367797   Low spender
# 24        1           6.367797   Low spender
# 25        1           6.367797   Low spender
# 26        1           6.367797   Low spender
# 27        1           6.367797   Low spender
# 28        1           6.367797   Low spender
# 29        1           6.367797   Low spender
# 30        1           6.367797   Low spender
# 31        1           6.367797   Low spender
# 32        1           6.367797   Low spender
# 33        1           6.367797   Low spender
# 34        1           6.367797   Low spender
# 35        1           6.367797   Low spender
# 36        1           6.367797   Low spender
# 37        1           6.367797   Low spender
# 38        1           6.367797   Low spender
# 39        1           6.367797   Low spender
# 40        1           6.367797   Low spender
# 41        1           6.367797   Low spender
# 42        1           6.367797   Low spender
# 43        1           6.367797   Low spender
# 44        1           6.367797   Low spender
# 45        1           6.367797   Low spender
# 46        1           6.367797   Low spender
# 47        1           6.367797   Low spender
# 48        1           6.367797   Low spender
# 49        1           6.367797   Low spender

# %% [markdown]
# ## Question 7

# %%
df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)
# Out:
# C:\Users\anish\AppData\Local\Temp\ipykernel_9288\1899012726.py:1: FutureWarning: The provided callable <function median at 0x0000023270A2F9C0> is currently using SeriesGroupBy.median. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "median" instead.
#   df_ords_prods_merge['median_days_between_orders'] = df_ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] > 20, 'order_frequency_flag'] = 'Non-frequent customer'
df_ords_prods_merge.loc[(df_ords_prods_merge['median_days_between_orders'] <= 20) & (df_ords_prods_merge['median_days_between_orders'] > 10), 'order_frequency_flag'] = 'Regular customer'
df_ords_prods_merge.loc[df_ords_prods_merge['median_days_between_orders'] <= 10, 'order_frequency_flag'] = 'Frequent customer'

# %%
df_ords_prods_merge['order_frequency_flag'].value_counts(dropna = False)
# Out:
# order_frequency_flag
# Frequent customer        21560324
# Regular customer          7209005
# Non-frequent customer     3636707
# NaN                             5
# Name: count, dtype: int64

# %%
df_ords_prods_merge[['user_id', 'days_since_prior_order', 'median_days_between_orders', 'order_frequency_flag']].head(50)
# Out:
#     user_id  days_since_prior_order  median_days_between_orders  \
# 0         1                     NaN                        20.5
# 1         1                     NaN                        20.5
# 2         1                     NaN                        20.5
# 3         1                     NaN                        20.5
# 4         1                     NaN                        20.5
# 5         1                    15.0                        20.5
# 6         1                    15.0                        20.5
# 7         1                    15.0                        20.5
# 8         1                    15.0                        20.5
# 9         1                    15.0                        20.5
# 10        1                    15.0                        20.5
# 11        1                    21.0                        20.5
# 12        1                    21.0                        20.5
# 13        1                    21.0                        20.5
# 14        1                    21.0                        20.5
# 15        1                    21.0                        20.5
# 16        1                    29.0                        20.5
# 17        1                    29.0                        20.5
# 18        1                    29.0                        20.5
# 19        1                    29.0                        20.5
# 20        1                    29.0                        20.5
# 21        1                    28.0                        20.5
# 22        1                    28.0                        20.5
# 23        1                    28.0                        20.5
# 24        1                    28.0                        20.5
# 25        1                    28.0                        20.5
# 26        1                    28.0                        20.5
# 27        1                    28.0                        20.5
# 28        1                    28.0                        20.5
# 29        1                    19.0                        20.5
# 30        1                    19.0                        20.5
# 31        1                    19.0                        20.5
# 32        1                    19.0                        20.5
# 33        1                    20.0                        20.5
# 34        1                    20.0                        20.5
# 35        1                    20.0                        20.5
# 36        1                    20.0                        20.5
# 37        1                    20.0                        20.5
# 38        1                    14.0                        20.5
# 39        1                    14.0                        20.5
# 40        1                    14.0                        20.5
# 41        1                    14.0                        20.5
# 42        1                    14.0                        20.5
# 43        1                    14.0                        20.5
# 44        1                     0.0                        20.5
# 45        1                     0.0                        20.5
# 46        1                     0.0                        20.5
# 47        1                     0.0                        20.5
# 48        1                     0.0                        20.5
# 49        1                     0.0                        20.5
#
#      order_frequency_flag
# 0   Non-frequent customer
# 1   Non-frequent customer
# 2   Non-frequent customer
# 3   Non-frequent customer
# 4   Non-frequent customer
# 5   Non-frequent customer
# 6   Non-frequent customer
# 7   Non-frequent customer
# 8   Non-frequent customer
# 9   Non-frequent customer
# 10  Non-frequent customer
# 11  Non-frequent customer
# 12  Non-frequent customer
# 13  Non-frequent customer
# 14  Non-frequent customer
# 15  Non-frequent customer
# 16  Non-frequent customer
# 17  Non-frequent customer
# 18  Non-frequent customer
# 19  Non-frequent customer
# 20  Non-frequent customer
# 21  Non-frequent customer
# 22  Non-frequent customer
# 23  Non-frequent customer
# 24  Non-frequent customer
# 25  Non-frequent customer
# 26  Non-frequent customer
# 27  Non-frequent customer
# 28  Non-frequent customer
# 29  Non-frequent customer
# 30  Non-frequent customer
# 31  Non-frequent customer
# 32  Non-frequent customer
# 33  Non-frequent customer
# 34  Non-frequent customer
# 35  Non-frequent customer
# 36  Non-frequent customer
# 37  Non-frequent customer
# 38  Non-frequent customer
# 39  Non-frequent customer
# 40  Non-frequent customer
# 41  Non-frequent customer
# 42  Non-frequent customer
# 43  Non-frequent customer
# 44  Non-frequent customer
# 45  Non-frequent customer
# 46  Non-frequent customer
# 47  Non-frequent customer
# 48  Non-frequent customer
# 49  Non-frequent customer

# %%
df_ords_prods_merge.to_pickle(os.path.join(path, 'Data', 'Prepared Data', 'orders_products_merged_aggregated.pkl'))
